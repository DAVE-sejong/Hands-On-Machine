# %% [markdown]
# ### 5.1 선형 SVM 분류
#
# svm은 특성의 스케일에 민감하다 그렇지않으면 그래프가 이상하게 나온다
# 마진에 데이터가 없고 실선으로 부터 최대한 멀리 떨어지게 만드는 것을 라지 마진 분류라고 합니다.
#
# ### 5.1.1 소프트 마진 분류
#
# 모든 샘플이 도로 밖으로 분류되어 있으면 하드마진분류 라고 한다.
# 하드마진 분류는 선형적으로 구분되어야하고 이상치에 민감하다.
# 이러한 문제를 피하려고 소프트 마진 분류 생겼다.
#
# SGDClassifier 모델을 사용하면 LinearSVC만큼 빠르게 수렴하지는 않지만
# 데이터셋이 아주크거나 온라인 학습으로 분류문제 다룰 때 유용하다.
#
# LinearSVC가 규제에 편향을 포함시키므로 평균을 빼서 중앙에 맞춰야한다.
# dual 매개변수란
# loss 매개변수
#
# ### 5.2.1 다항식 커널
#
# 커널 트릭은 특성을 추가하지 않으면서 다항식 특성을 많이 추가한것과 같은 결과를 얻는다.
# 모델이 과대적합이라면 다항식 차수를 줄여야한다.
#
# ### 5.2.2 유사도 특성 추가
#
# 각 샘플이 특정 랜드마크와 얼마나 닮았는지 측정하는 유사도 함수로 계산한 특성을 추가하는것
#
#
# ### 5.2.3 가우시안 RBF 커널
# r이 규제의 역할을 한다.
# 모델이 과대적합일 경우 감소시켜야하고
# 과소적합일 경우 증가시켜야한다.
#
#
# ### 5.3 SVM 회귀
#
# 제한된 마진 오류 안에서 도로 안에 가능한 한 많은 샘플이 들어가도록 학습한다.
#
# SVR은 어떤식으로 나오나
#
#
# ### 5.4 SVM 이론
# ### 5.4.1 결정함수와 예측
